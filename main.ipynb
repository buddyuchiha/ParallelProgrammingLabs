# %% [markdown]
# __Отчет по первой ЛР__

# %% [markdown]
# Проверка результатов

# %%
from functions import *

first_matrix = "ParallelProgrammingLab1\\input\\first_matrix\\first_matrix100.txt"
second_matrix = "ParallelProgrammingLab1\\input\\second_matrix\\secind_matrix100.txt"
result_matrix = "ParallelProgrammingLab1\\output\\result\\result100.txt"

result = result_checker(first_matrix, second_matrix, result_matrix)
print(result)
# Out:
# True

# %% [markdown]
# Обработка результатов

# %%
import matplotlib.pyplot as plt

from functions import read_time

x = []
y = []
for size in range(100, 1100, 100):
    x.append(size)
    y.append(read_time(f"ParallelProgrammingLab1\\output\\time\\time{size}.txt"))

plt.plot(x, y, label="result", color="blue")
plt.xlabel("matrix size")
plt.ylabel("time in ms")
# Out:
# Text(0, 0.5, 'time in ms')
